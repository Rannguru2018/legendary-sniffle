# %%
import requests
import string
from bs4 import BeautifulSoup
def get_latest_python_articles():
    url="https://www.python.org/"
    response=requests.get(url)
    
    if response.status_code== 200:
        soup=BeautifulSoup(response.text,"html.parser")
        latest_articles=[]
        
        for article in soup.select(".blog-widget li"):
            title=article.a.text.strip()
            latest_articles.append(title)
            
        return latest_articles
    else:
            print(f"Failed to retrieve data. Status code:{response.status_code}")
            return []
if __name__=="__main__":
    python_articles = get_latest_python_articles()
    
    if python_articles:
            print("Latest articles in the Python section:")
            for index,article in enumerate(python_articles,1):
                print(f"{index}.{article}")
            else:
                print("No article Found.")
# Out:
# Latest articles in the Python section:
# 1.September & October Board Votes
# 2.Security Developer-in-Residence 2023 Q3 Report
# 3.Python 3.13.0 alpha 1 is now available
# 4.Python 3.11.6 is now available
# 5.Python 3.12.0 (final) now available
# No article Found.

# %%
from collections import Counter
import re

def count_words(file_name):
    with open(file_name, 'r') as file:
        text = file.read().lower()
        words = re.findall(r'\b\w+\b', text)
        word_count = Counter(words)
        
    return word_count

file_name ='WORD SCRAPING.tex' 
word_count = count_words(file_name)
for word, count in word_count.items():
    print(f'Word: {word}, Frequency: {count}')
# Out:
# Word: documentclass, Frequency: 1
# Word: 11pt, Frequency: 1
# Word: article, Frequency: 7
# Word: usepackage, Frequency: 32
# Word: breakable, Frequency: 5
# Word: tcolorbox, Frequency: 9
# Word: parskip, Frequency: 3
# Word: stop, Frequency: 1
# Word: auto, Frequency: 1
# Word: indenting, Frequency: 1
# Word: to, Frequency: 16
# Word: mimic, Frequency: 1
# Word: markdown, Frequency: 3
# Word: behaviour, Frequency: 1
# Word: basic, Frequency: 1
# Word: figure, Frequency: 3
# Word: setup, Frequency: 2
# Word: for, Frequency: 21
# Word: now, Frequency: 4
# Word: with, Frequency: 6
# Word: no, Frequency: 5
# Word: caption, Frequency: 4
# Word: control, Frequency: 1
# Word: since, Frequency: 1
# Word: it, Frequency: 14
# Word: s, Frequency: 35
# Word: done, Frequency: 1
# Word: automatically, Frequency: 1
# Word: by, Frequency: 5
# Word: pandoc, Frequency: 8
# Word: which, Frequency: 1
# Word: extracts, Frequency: 1
# Word: path, Frequency: 1
# Word: syntax, Frequency: 1
# Word: from, Frequency: 6
# Word: graphicx, Frequency: 1
# Word: maintain, Frequency: 1
# Word: compatibility, Frequency: 3
# Word: old, Frequency: 2
# Word: templates, Frequency: 1
# Word: remove, Frequency: 1
# Word: in, Frequency: 11
# Word: nbconvert, Frequency: 1
# Word: 6, Frequency: 2
# Word: 0, Frequency: 273
# Word: let, Frequency: 35
# Word: oldincludegraphics, Frequency: 1
# Word: includegraphics, Frequency: 1
# Word: ensure, Frequency: 1
# Word: that, Frequency: 4
# Word: default, Frequency: 5
# Word: figures, Frequency: 2
# Word: have, Frequency: 1
# Word: until, Frequency: 1
# Word: we, Frequency: 1
# Word: provide, Frequency: 1
# Word: a, Frequency: 13
# Word: proper, Frequency: 1
# Word: object, Frequency: 1
# Word: api, Frequency: 1
# Word: and, Frequency: 7
# Word: way, Frequency: 1
# Word: capture, Frequency: 1
# Word: the, Frequency: 18
# Word: conversion, Frequency: 1
# Word: process, Frequency: 1
# Word: todo, Frequency: 1
# Word: declarecaptionformat, Frequency: 1
# Word: nocaption, Frequency: 2
# Word: captionsetup, Frequency: 1
# Word: format, Frequency: 1
# Word: aboveskip, Frequency: 1
# Word: 0pt, Frequency: 4
# Word: belowskip, Frequency: 1
# Word: float, Frequency: 1
# Word: floatplacement, Frequency: 1
# Word: h, Frequency: 1
# Word: forces, Frequency: 1
# Word: be, Frequency: 4
# Word: placed, Frequency: 1
# Word: at, Frequency: 10
# Word: correct, Frequency: 1
# Word: location, Frequency: 1
# Word: xcolor, Frequency: 1
# Word: allow, Frequency: 2
# Word: colors, Frequency: 4
# Word: defined, Frequency: 1
# Word: enumerate, Frequency: 3
# Word: needed, Frequency: 3
# Word: enumerations, Frequency: 1
# Word: work, Frequency: 1
# Word: geometry, Frequency: 2
# Word: used, Frequency: 2
# Word: adjust, Frequency: 1
# Word: document, Frequency: 5
# Word: margins, Frequency: 2
# Word: amsmath, Frequency: 1
# Word: equations, Frequency: 2
# Word: amssymb, Frequency: 1
# Word: textcomp, Frequency: 1
# Word: defines, Frequency: 2
# Word: textquotesingle, Frequency: 5
# Word: hack, Frequency: 1
# Word: http, Frequency: 1
# Word: tex, Frequency: 4
# Word: stackexchange, Frequency: 1
# Word: com, Frequency: 1
# Word: 47451, Frequency: 1
# Word: 13684, Frequency: 1
# Word: atbegindocument, Frequency: 1
# Word: def, Frequency: 117
# Word: pyzsq, Frequency: 2
# Word: upright, Frequency: 2
# Word: quotes, Frequency: 2
# Word: pygmentized, Frequency: 2
# Word: code, Frequency: 5
# Word: upquote, Frequency: 1
# Word: verbatim, Frequency: 16
# Word: eurosym, Frequency: 1
# Word: euro, Frequency: 1
# Word: iftex, Frequency: 1
# Word: ifpdftex, Frequency: 1
# Word: t1, Frequency: 1
# Word: fontenc, Frequency: 1
# Word: iffileexists, Frequency: 2
# Word: alphabeta, Frequency: 2
# Word: sty, Frequency: 1
# Word: mathletters, Frequency: 1
# Word: ucs, Frequency: 1
# Word: utf8x, Frequency: 1
# Word: inputenc, Frequency: 1
# Word: else, Frequency: 4
# Word: fontspec, Frequency: 1
# Word: unicode, Frequency: 1
# Word: math, Frequency: 2
# Word: fi, Frequency: 2
# Word: fancyvrb, Frequency: 2
# Word: replacement, Frequency: 1
# Word: allows, Frequency: 1
# Word: latex, Frequency: 5
# Word: grffile, Frequency: 3
# Word: extends, Frequency: 1
# Word: file, Frequency: 1
# Word: name, Frequency: 2
# Word: processing, Frequency: 2
# Word: of, Frequency: 11
# Word: package, Frequency: 5
# Word: graphics, Frequency: 1
# Word: support, Frequency: 6
# Word: larger, Frequency: 1
# Word: range, Frequency: 1
# Word: makeatletter, Frequency: 5
# Word: fix, Frequency: 1
# Word: versions, Frequency: 4
# Word: xelatex, Frequency: 1
# Word: ifpackagelater, Frequency: 1
# Word: 2019, Frequency: 1
# Word: 11, Frequency: 5
# Word: 01, Frequency: 2
# Word: do, Frequency: 3
# Word: nothing, Frequency: 1
# Word: on, Frequency: 1
# Word: new, Frequency: 1
# Word: gread, Frequency: 3
# Word: xetex, Frequency: 2
# Word: 1, Frequency: 227
# Word: gin, Frequency: 2
# Word: base, Frequency: 2
# Word: bb, Frequency: 2
# Word: eps, Frequency: 1
# Word: aux, Frequency: 1
# Word: makeatother, Frequency: 5
# Word: export, Frequency: 1
# Word: adjustbox, Frequency: 1
# Word: constrain, Frequency: 1
# Word: images, Frequency: 1
# Word: maximum, Frequency: 1
# Word: size, Frequency: 6
# Word: adjustboxset, Frequency: 1
# Word: max, Frequency: 1
# Word: 9, Frequency: 2
# Word: linewidth, Frequency: 2
# Word: paperheight, Frequency: 1
# Word: hyperref, Frequency: 4
# Word: gives, Frequency: 1
# Word: us, Frequency: 1
# Word: pdf, Frequency: 2
# Word: properly, Frequency: 1
# Word: built, Frequency: 1
# Word: internal, Frequency: 2
# Word: navigation, Frequency: 1
# Word: bookmarks, Frequency: 1
# Word: table, Frequency: 4
# Word: contents, Frequency: 1
# Word: cross, Frequency: 1
# Word: reference, Frequency: 1
# Word: links, Frequency: 2
# Word: web, Frequency: 1
# Word: urls, Frequency: 2
# Word: etc, Frequency: 1
# Word: title, Frequency: 5
# Word: has, Frequency: 1
# Word: an, Frequency: 1
# Word: obnoxious, Frequency: 1
# Word: amount, Frequency: 1
# Word: whitespace, Frequency: 1
# Word: titling, Frequency: 2
# Word: removes, Frequency: 1
# Word: some, Frequency: 2
# Word: also, Frequency: 1
# Word: provides, Frequency: 1
# Word: customization, Frequency: 1
# Word: options, Frequency: 1
# Word: longtable, Frequency: 2
# Word: required, Frequency: 1
# Word: 10, Frequency: 8
# Word: booktabs, Frequency: 1
# Word: 12, Frequency: 4
# Word: 2, Frequency: 9
# Word: array, Frequency: 1
# Word: 3, Frequency: 6
# Word: calc, Frequency: 1
# Word: minipage, Frequency: 1
# Word: width, Frequency: 1
# Word: calculation, Frequency: 1
# Word: inline, Frequency: 1
# Word: enumitem, Frequency: 1
# Word: irkernel, Frequency: 1
# Word: repr, Frequency: 1
# Word: uses, Frequency: 1
# Word: environment, Frequency: 2
# Word: normalem, Frequency: 2
# Word: ulem, Frequency: 2
# Word: is, Frequency: 4
# Word: strikethroughs, Frequency: 1
# Word: sout, Frequency: 1
# Word: makes, Frequency: 2
# Word: italics, Frequency: 2
# Word: not, Frequency: 2
# Word: underlines, Frequency: 1
# Word: mathrsfs, Frequency: 1
# Word: definecolor, Frequency: 26
# Word: urlcolor, Frequency: 3
# Word: rgb, Frequency: 94
# Word: 145, Frequency: 1
# Word: 698, Frequency: 1
# Word: linkcolor, Frequency: 3
# Word: 71, Frequency: 1
# Word: 21, Frequency: 1
# Word: citecolor, Frequency: 3
# Word: 54, Frequency: 1
# Word: ansi, Frequency: 19
# Word: black, Frequency: 2
# Word: html, Frequency: 24
# Word: 3e424d, Frequency: 1
# Word: intense, Frequency: 8
# Word: 282c36, Frequency: 1
# Word: red, Frequency: 4
# Word: e75c58, Frequency: 1
# Word: b22b31, Frequency: 1
# Word: green, Frequency: 2
# Word: 00a250, Frequency: 1
# Word: 007427, Frequency: 1
# Word: yellow, Frequency: 2
# Word: ddb62b, Frequency: 1
# Word: b27d12, Frequency: 1
# Word: blue, Frequency: 2
# Word: 208ffb, Frequency: 1
# Word: 0065ca, Frequency: 1
# Word: magenta, Frequency: 2
# Word: d160c4, Frequency: 1
# Word: a03196, Frequency: 1
# Word: cyan, Frequency: 2
# Word: 60c6c8, Frequency: 1
# Word: 258f8f, Frequency: 1
# Word: white, Frequency: 2
# Word: c5c1b4, Frequency: 1
# Word: a1a6b2, Frequency: 1
# Word: inverse, Frequency: 2
# Word: fg, Frequency: 1
# Word: ffffff, Frequency: 1
# Word: bg, Frequency: 1
# Word: 000000, Frequency: 1
# Word: common, Frequency: 1
# Word: color, Frequency: 2
# Word: border, Frequency: 1
# Word: error, Frequency: 1
# Word: outputs, Frequency: 1
# Word: outerrorbackground, Frequency: 1
# Word: ffdfdf, Frequency: 1
# Word: commands, Frequency: 2
# Word: environments, Frequency: 1
# Word: snippets, Frequency: 1
# Word: extracted, Frequency: 1
# Word: output, Frequency: 1
# Word: providecommand, Frequency: 1
# Word: tightlist, Frequency: 1
# Word: setlength, Frequency: 3
# Word: itemsep, Frequency: 1
# Word: defineverbatimenvironment, Frequency: 1
# Word: highlighting, Frequency: 1
# Word: commandchars, Frequency: 6
# Word: add, Frequency: 2
# Word: fontsize, Frequency: 1
# Word: small, Frequency: 1
# Word: more, Frequency: 2
# Word: characters, Frequency: 4
# Word: per, Frequency: 1
# Word: line, Frequency: 6
# Word: newenvironment, Frequency: 1
# Word: shaded, Frequency: 1
# Word: newcommand, Frequency: 39
# Word: keywordtok, Frequency: 1
# Word: textcolor, Frequency: 92
# Word: 00, Frequency: 67
# Word: 44, Frequency: 16
# Word: 13, Frequency: 28
# Word: textbf, Frequency: 25
# Word: datatypetok, Frequency: 1
# Word: 56, Frequency: 2
# Word: decvaltok, Frequency: 1
# Word: 25, Frequency: 9
# Word: 63, Frequency: 13
# Word: basentok, Frequency: 1
# Word: floattok, Frequency: 1
# Word: chartok, Frequency: 1
# Word: stringtok, Frequency: 1
# Word: commenttok, Frequency: 1
# Word: 38, Frequency: 5
# Word: 69, Frequency: 6
# Word: textit, Frequency: 14
# Word: othertok, Frequency: 1
# Word: alerttok, Frequency: 1
# Word: functiontok, Frequency: 1
# Word: 02, Frequency: 1
# Word: 16, Frequency: 2
# Word: 49, Frequency: 9
# Word: regionmarkertok, Frequency: 1
# Word: errortok, Frequency: 1
# Word: normaltok, Frequency: 1
# Word: additional, Frequency: 1
# Word: recent, Frequency: 1
# Word: constanttok, Frequency: 1
# Word: 53, Frequency: 3
# Word: specialchartok, Frequency: 1
# Word: verbatimstringtok, Frequency: 1
# Word: specialstringtok, Frequency: 1
# Word: 73, Frequency: 14
# Word: 40, Frequency: 29
# Word: importtok, Frequency: 1
# Word: documentationtok, Frequency: 1
# Word: annotationtok, Frequency: 1
# Word: commentvartok, Frequency: 1
# Word: variabletok, Frequency: 1
# Word: 09, Frequency: 7
# Word: controlflowtok, Frequency: 1
# Word: operatortok, Frequency: 1
# Word: builtintok, Frequency: 1
# Word: extensiontok, Frequency: 1
# Word: preprocessortok, Frequency: 1
# Word: 74, Frequency: 1
# Word: 48, Frequency: 13
# Word: attributetok, Frequency: 1
# Word: informationtok, Frequency: 1
# Word: warningtok, Frequency: 1
# Word: define, Frequency: 1
# Word: nice, Frequency: 1
# Word: break, Frequency: 6
# Word: command, Frequency: 1
# Word: doesn, Frequency: 2
# Word: t, Frequency: 2
# Word: care, Frequency: 1
# Word: if, Frequency: 5
# Word: already, Frequency: 2
# Word: exist, Frequency: 1
# Word: br, Frequency: 1
# Word: hspace, Frequency: 2
# Word: fill, Frequency: 1
# Word: jax, Frequency: 1
# Word: definitions, Frequency: 2
# Word: gt, Frequency: 2
# Word: lt, Frequency: 1
# Word: oldtex, Frequency: 2
# Word: oldlatex, Frequency: 2
# Word: renewcommand, Frequency: 3
# Word: textrm, Frequency: 2
# Word: parameters, Frequency: 1
# Word: word, Frequency: 1
# Word: scraping, Frequency: 1
# Word: pygments, Frequency: 2
# Word: py, Frequency: 333
# Word: reset, Frequency: 2
# Word: relax, Frequency: 8
# Word: bf, Frequency: 19
# Word: ul, Frequency: 2
# Word: tc, Frequency: 66
# Word: bc, Frequency: 3
# Word: ff, Frequency: 2
# Word: tok, Frequency: 70
# Word: csname, Frequency: 1
# Word: endcsname, Frequency: 1
# Word: toks, Frequency: 3
# Word: ifx, Frequency: 1
# Word: empty, Frequency: 1
# Word: expandafter, Frequency: 1
# Word: namedef, Frequency: 67
# Word: w, Frequency: 1
# Word: c, Frequency: 2
# Word: 24, Frequency: 6
# Word: cp, Frequency: 1
# Word: 61, Frequency: 1
# Word: k, Frequency: 16
# Word: 50, Frequency: 14
# Word: kp, Frequency: 1
# Word: kt, Frequency: 1
# Word: o, Frequency: 21
# Word: ow, Frequency: 3
# Word: 67, Frequency: 3
# Word: nb, Frequency: 7
# Word: nf, Frequency: 2
# Word: nc, Frequency: 1
# Word: nn, Frequency: 4
# Word: ne, Frequency: 1
# Word: 80, Frequency: 1
# Word: 22, Frequency: 1
# Word: nv, Frequency: 2
# Word: nl, Frequency: 1
# Word: 46, Frequency: 2
# Word: ni, Frequency: 1
# Word: na, Frequency: 1
# Word: 41, Frequency: 1
# Word: 47, Frequency: 3
# Word: nt, Frequency: 1
# Word: nd, Frequency: 1
# Word: sd, Frequency: 1
# Word: si, Frequency: 7
# Word: 64, Frequency: 2
# Word: 35, Frequency: 2
# Word: se, Frequency: 1
# Word: 36, Frequency: 1
# Word: sr, Frequency: 1
# Word: ss, Frequency: 1
# Word: sx, Frequency: 1
# Word: m, Frequency: 4
# Word: gh, Frequency: 1
# Word: gu, Frequency: 1
# Word: gd, Frequency: 1
# Word: gi, Frequency: 1
# Word: 52, Frequency: 1
# Word: gr, Frequency: 1
# Word: 89, Frequency: 1
# Word: ge, Frequency: 1
# Word: gs, Frequency: 1
# Word: gp, Frequency: 1
# Word: go, Frequency: 2
# Word: 27, Frequency: 1
# Word: 87, Frequency: 1
# Word: err, Frequency: 1
# Word: fboxsep, Frequency: 1
# Word: string, Frequency: 2
# Word: fboxrule, Frequency: 1
# Word: fcolorbox, Frequency: 1
# Word: strut, Frequency: 3
# Word: kc, Frequency: 1
# Word: kd, Frequency: 1
# Word: kn, Frequency: 5
# Word: kr, Frequency: 1
# Word: bp, Frequency: 1
# Word: fm, Frequency: 1
# Word: vc, Frequency: 1
# Word: vg, Frequency: 1
# Word: vi, Frequency: 1
# Word: vm, Frequency: 2
# Word: sa, Frequency: 3
# Word: sb, Frequency: 1
# Word: sc, Frequency: 1
# Word: dl, Frequency: 1
# Word: s2, Frequency: 25
# Word: sh, Frequency: 1
# Word: s1, Frequency: 1
# Word: mb, Frequency: 1
# Word: mf, Frequency: 1
# Word: mh, Frequency: 1
# Word: mi, Frequency: 3
# Word: il, Frequency: 1
# Word: mo, Frequency: 1
# Word: ch, Frequency: 1
# Word: cm, Frequency: 1
# Word: cpf, Frequency: 1
# Word: c1, Frequency: 1
# Word: cs, Frequency: 1
# Word: pyzbs, Frequency: 1
# Word: char, Frequency: 55
# Word: pyzus, Frequency: 23
# Word: _, Frequency: 4
# Word: pyzob, Frequency: 4
# Word: pyzcb, Frequency: 4
# Word: pyzca, Frequency: 1
# Word: pyzam, Frequency: 1
# Word: pyzlt, Frequency: 1
# Word: pyzgt, Frequency: 1
# Word: pyzsh, Frequency: 1
# Word: pyzpc, Frequency: 2
# Word: pyzdl, Frequency: 1
# Word: pyzhy, Frequency: 2
# Word: pyzdq, Frequency: 17
# Word: pyzti, Frequency: 1
# Word: earlier, Frequency: 1
# Word: pyzat, Frequency: 1
# Word: pyzlb, Frequency: 1
# Word: pyzrb, Frequency: 1
# Word: linebreaks, Frequency: 3
# Word: inside, Frequency: 1
# Word: newbox, Frequency: 2
# Word: wrappedcontinuationbox, Frequency: 3
# Word: wrappedvisiblespacebox, Frequency: 3
# Word: wrappedvisiblespace, Frequency: 2
# Word: textvisiblespace, Frequency: 1
# Word: wrappedcontinuationsymbol, Frequency: 2
# Word: llap, Frequency: 2
# Word: tiny, Frequency: 1
# Word: th, Frequency: 1
# Word: hookrightarrow, Frequency: 1
# Word: wrappedcontinuationindent, Frequency: 2
# Word: 3ex, Frequency: 1
# Word: wrappedafterbreak, Frequency: 23
# Word: kern, Frequency: 4
# Word: copy, Frequency: 2
# Word: take, Frequency: 1
# Word: advantage, Frequency: 1
# Word: applied, Frequency: 1
# Word: mark, Frequency: 1
# Word: up, Frequency: 1
# Word: insert, Frequency: 2
# Word: potential, Frequency: 2
# Word: next, Frequency: 2
# Word: stay, Frequency: 1
# Word: end, Frequency: 12
# Word: broken, Frequency: 2
# Word: use, Frequency: 1
# Word: straight, Frequency: 1
# Word: quote, Frequency: 1
# Word: wrappedbreaksatspecials, Frequency: 2
# Word: pygzus, Frequency: 1
# Word: discretionary, Frequency: 22
# Word: pygzob, Frequency: 1
# Word: pygzcb, Frequency: 1
# Word: pygzca, Frequency: 1
# Word: pygzam, Frequency: 1
# Word: pygzlt, Frequency: 1
# Word: pygzgt, Frequency: 1
# Word: pygzsh, Frequency: 1
# Word: pygzpc, Frequency: 1
# Word: pygzdl, Frequency: 1
# Word: pygzhy, Frequency: 1
# Word: pygzsq, Frequency: 1
# Word: pygzdq, Frequency: 1
# Word: pygzti, Frequency: 1
# Word: are, Frequency: 3
# Word: this, Frequency: 1
# Word: macro, Frequency: 1
# Word: them, Frequency: 1
# Word: active, Frequency: 9
# Word: they, Frequency: 1
# Word: will, Frequency: 2
# Word: wrappedbreaksatpunct, Frequency: 2
# Word: lccode, Frequency: 8
# Word: lowercase, Frequency: 7
# Word: hbox, Frequency: 14
# Word: catcode, Frequency: 8
# Word: originalverbatim, Frequency: 2
# Word: z, Frequency: 6
# Word: skip, Frequency: 1
# Word: sbox, Frequency: 2
# Word: fv, Frequency: 2
# Word: setupfont, Frequency: 1
# Word: fancyverbformatline, Frequency: 1
# Word: hsize, Frequency: 1
# Word: vtop, Frequency: 1
# Word: raggedright, Frequency: 1
# Word: hyphenpenalty, Frequency: 1
# Word: exhyphenpenalty, Frequency: 1
# Word: doublehyphendemerits, Frequency: 1
# Word: finalhyphendemerits, Frequency: 1
# Word: linebreak, Frequency: 1
# Word: space, Frequency: 3
# Word: latter, Frequency: 1
# Word: displayed, Frequency: 1
# Word: as, Frequency: 1
# Word: visible, Frequency: 1
# Word: first, Frequency: 1
# Word: continuation, Frequency: 1
# Word: symbol, Frequency: 1
# Word: starts, Frequency: 1
# Word: stretch, Frequency: 1
# Word: shrink, Frequency: 1
# Word: however, Frequency: 1
# Word: usually, Frequency: 1
# Word: zero, Frequency: 1
# Word: typewriter, Frequency: 1
# Word: font, Frequency: 4
# Word: nobreak, Frequency: 1
# Word: hskip, Frequency: 1
# Word: plus, Frequency: 1
# Word: fontdimen3, Frequency: 1
# Word: minus, Frequency: 1
# Word: fontdimen4, Frequency: 1
# Word: fontdimen2, Frequency: 1
# Word: breaks, Frequency: 2
# Word: special, Frequency: 1
# Word: using, Frequency: 1
# Word: pyg, Frequency: 1
# Word: macros, Frequency: 1
# Word: punctuation, Frequency: 1
# Word: need, Frequency: 1
# Word: codes, Frequency: 1
# Word: exact, Frequency: 1
# Word: incolor, Frequency: 4
# Word: 303f9f, Frequency: 1
# Word: outcolor, Frequency: 2
# Word: d84315, Frequency: 1
# Word: cellborder, Frequency: 4
# Word: cfcfcf, Frequency: 1
# Word: cellbackground, Frequency: 4
# Word: f7f7f7, Frequency: 1
# Word: prompt, Frequency: 6
# Word: boxspacing, Frequency: 5
# Word: kvtcb, Frequency: 2
# Word: left, Frequency: 1
# Word: rule, Frequency: 1
# Word: boxsep, Frequency: 1
# Word: 4, Frequency: 3
# Word: ttfamily, Frequency: 1
# Word: 3pt, Frequency: 1
# Word: vspace, Frequency: 1
# Word: baselineskip, Frequency: 1
# Word: prevent, Frequency: 1
# Word: overflowing, Frequency: 1
# Word: lines, Frequency: 2
# Word: due, Frequency: 1
# Word: hard, Frequency: 1
# Word: entities, Frequency: 1
# Word: sloppy, Frequency: 1
# Word: hypersetup, Frequency: 1
# Word: breaklinks, Frequency: 1
# Word: true, Frequency: 2
# Word: so, Frequency: 1
# Word: long, Frequency: 1
# Word: correctly, Frequency: 1
# Word: across, Frequency: 1
# Word: colorlinks, Frequency: 1
# Word: slightly, Frequency: 1
# Word: bigger, Frequency: 1
# Word: than, Frequency: 1
# Word: defaults, Frequency: 1
# Word: verbose, Frequency: 1
# Word: tmargin, Frequency: 1
# Word: 1in, Frequency: 4
# Word: bmargin, Frequency: 1
# Word: lmargin, Frequency: 1
# Word: rmargin, Frequency: 1
# Word: begin, Frequency: 10
# Word: maketitle, Frequency: 1
# Word: fbox, Frequency: 4
# Word: boxrule, Frequency: 4
# Word: 1pt, Frequency: 3
# Word: pad, Frequency: 4
# Word: 1mm, Frequency: 4
# Word: colback, Frequency: 3
# Word: colframe, Frequency: 3
# Word: import, Frequency: 3
# Word: n, Frequency: 45
# Word: requests, Frequency: 2
# Word: bs4, Frequency: 1
# Word: beautifulsoup, Frequency: 2
# Word: get, Frequency: 3
# Word: latest, Frequency: 7
# Word: python, Frequency: 11
# Word: articles, Frequency: 10
# Word: p, Frequency: 39
# Word: url, Frequency: 2
# Word: l, Frequency: 34
# Word: https, Frequency: 1
# Word: www, Frequency: 1
# Word: org, Frequency: 1
# Word: response, Frequency: 4
# Word: status, Frequency: 3
# Word: 200, Frequency: 1
# Word: soup, Frequency: 2
# Word: text, Frequency: 2
# Word: parser, Frequency: 1
# Word: select, Frequency: 1
# Word: blog, Frequency: 1
# Word: widget, Frequency: 1
# Word: li, Frequency: 1
# Word: strip, Frequency: 1
# Word: append, Frequency: 1
# Word: return, Frequency: 2
# Word: print, Frequency: 4
# Word: f, Frequency: 2
# Word: failed, Frequency: 1
# Word: retrieve, Frequency: 1
# Word: data, Frequency: 1
# Word: main, Frequency: 1
# Word: section, Frequency: 2
# Word: index, Frequency: 2
# Word: found, Frequency: 2
# Word: september, Frequency: 1
# Word: october, Frequency: 1
# Word: board, Frequency: 1
# Word: votes, Frequency: 1
# Word: security, Frequency: 1
# Word: developer, Frequency: 1
# Word: residence, Frequency: 1
# Word: 2023, Frequency: 1
# Word: q3, Frequency: 1
# Word: report, Frequency: 1
# Word: alpha, Frequency: 1
# Word: available, Frequency: 3
# Word: 5, Frequency: 1
# Word: final, Frequency: 1
# Word: pwd, Frequency: 1
# Word: 5pt, Frequency: 1
# Word: opacityfill, Frequency: 1
# Word: out, Frequency: 1
# Word: textbackslash, Frequency: 6
# Word: users, Frequency: 1
# Word: rites, Frequency: 1
# Word: ai, Frequency: 1
# Word: course, Frequency: 1
# Word: digicrome, Frequency: 1
# Word: bibliography, Frequency: 1
# Word: block, Frequency: 1
# Word: postdoc, Frequency: 1
